# %% [markdown]
# # Assignment 3 - Building a Custom Visualization
#
# ---
#
# In this assignment you must choose one of the options presented below and submit a visual as well as your source code for peer grading. The details of how you solve the assignment are up to you, although your assignment must use matplotlib so that your peers can evaluate your work. The options differ in challenge level, but there are no grades associated with the challenge level you chose. However, your peers will be asked to ensure you at least met a minimum quality for a given technique in order to pass. Implement the technique fully (or exceed it!) and you should be able to earn full grades for the assignment.
#
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Ferreira, N., Fisher, D., & Konig, A. C. (2014, April). [Sample-oriented task-driven visualizations: allowing users to make better, more confident decisions.](https://www.microsoft.com/en-us/research/wp-content/uploads/2016/02/Ferreira_Fisher_Sample_Oriented_Tasks.pdf)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;In Proceedings of the SIGCHI Conference on Human Factors in Computing Systems (pp. 571-580). ACM. ([video](https://www.youtube.com/watch?v=BI7GAs-va-Q))
#
#
# In this [paper](https://www.microsoft.com/en-us/research/wp-content/uploads/2016/02/Ferreira_Fisher_Sample_Oriented_Tasks.pdf) the authors describe the challenges users face when trying to make judgements about probabilistic data generated through samples. As an example, they look at a bar chart of four years of data (replicated below in Figure 1). Each year has a y-axis value, which is derived from a sample of a larger dataset. For instance, the first value might be the number votes in a given district or riding for 1992, with the average being around 33,000. On top of this is plotted the 95% confidence interval for the mean (see the boxplot lectures for more information, and the yerr parameter of barcharts).
#
# <br>
# <img src="readonly/Assignment3Fig1.png" alt="Figure 1" style="width: 400px;"/>
# <h4 style="text-align: center;" markdown="1">  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Figure 1 from (Ferreira et al, 2014).</h4>
#
# <br>
#
# A challenge that users face is that, for a given y-axis value (e.g. 42,000), it is difficult to know which x-axis values are most likely to be representative, because the confidence levels overlap and their distributions are different (the lengths of the confidence interval bars are unequal). One of the solutions the authors propose for this problem (Figure 2c) is to allow users to indicate the y-axis value of interest (e.g. 42,000) and then draw a horizontal line and color bars based on this value. So bars might be colored red if they are definitely above this value (given the confidence interval), blue if they are definitely below this value, or white if they contain this value.
#
#
# <br>
# <img src="readonly/Assignment3Fig2c.png" alt="Figure 1" style="width: 400px;"/>
# <h4 style="text-align: center;" markdown="1">  Figure 2c from (Ferreira et al. 2014). Note that the colorbar legend at the bottom as well as the arrows are not required in the assignment descriptions below.</h4>
#
# <br>
# <br>
#
# **Easiest option:** Implement the bar coloring as described above - a color scale with only three colors, (e.g. blue, white, and red). Assume the user provides the y axis value of interest as a parameter or variable.
#
#
# **Harder option:** Implement the bar coloring as described in the paper, where the color of the bar is actually based on the amount of data covered (e.g. a gradient ranging from dark blue for the distribution being certainly below this y-axis, to white if the value is certainly contained, to dark red if the value is certainly not contained as the distribution is above the axis).
#
# **Even Harder option:** Add interactivity to the above, which allows the user to click on the y axis to set the value of interest. The bar colors should change with respect to what value the user has selected.
#
# **Hardest option:** Allow the user to interactively set a range of y values they are interested in, and recolor based on this (e.g. a y-axis band, see the paper for more details).
#
# ---
#
# *Note: The data given for this assignment is not the same as the data used in the article and as a result the visualizations may look a little different.*

# %%
# Use the following data for this assignment:

import pandas as pd
import numpy as np

np.random.seed(12345)

df = pd.DataFrame([np.random.normal(32000,200000,3650), 
                   np.random.normal(43000,100000,3650), 
                   np.random.normal(43500,140000,3650), 
                   np.random.normal(48000,70000,3650)], 
                  index=[1992,1993,1994,1995])


df
# Out:
#                0              1              2              3     \
# 1992   -8941.531897  127788.667612  -71887.743011  -79146.060869
# 1993  -51896.094813  198350.518755 -123518.252821 -129916.759685
# 1994  152336.932066  192947.128056  389950.263156  -93006.152024
# 1995  -69708.439062  -13289.977022  -30178.390991   55052.181256
#
#                4              5              6              7     \
# 1992  425156.114501  310681.166595   50581.575349   88349.230566
# 1993  216119.147314   49845.883728  149135.648505   62807.672113
# 1994  100818.575896    5529.230706  -32989.370488  223942.967178
# 1995  152883.621657   12930.835194   63700.461932   64148.489835
#
#                8              9         ...                3640  \
# 1992  185804.513522  281286.947277      ...       171938.760289
# 1993   23365.577348 -109686.264981      ...       -44566.520071
# 1994  -66721.580898   47826.269111      ...       165085.806360
# ...

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from matplotlib.widgets import Slider, Button, RadioButtons, Cursor, SpanSelector
from scipy.stats import sem # standard error mean
from IPython.core.debugger import set_trace
# %matplotlib notebook


class InteractiveBarChart(object):
    """Creates an interactive bar chart based on the dataframe passed.
    
    Keyword arguments:
    df -- DataFrame object to draw from
    axis -- Choices: 0 (columns), 1 (rows), 'auto' (will determine automatically,
            see the check_df_shape method for more details).
    """
    df = None
    descriptions = None
    
    sub_df = None
    sub_desc = None
    
    reset = None
    cursor = None
    
    plt = None
    fig = None
    ax = None
    
    radio_ax = None
    radio = None
    
    vmin = None
    vmax = None
    
    config = None
    
    # color palette
    palette = None
    _std_palette = {
                'const_gradient': [
                    '#022F61',#0
                    '#1C64AE',#1
                    '#3F92C5',#2
                    '#90C5E0',#3
                    '#D1E5F1',#4
                    '#F7F7F7',#5
                    '#FEDBC6',#6
                    '#F6A57E',
                    '#D85F48',
                    '#B41427',
                    '#68001E',
                ],
                'range_gradient': [
                    '#FFF7EC',
                    '#FEE8C8',
                    '#FDD49E',
                    '#FDBB84',
                    '#FC8D59',
                    '#EF6548',
                    '#D7301F',
                    '#B30000',
                    '#7F0000',
                ],
                'background': '#000000',
                'widget_bg': '#f2e8bf',
                'widget_fg': '#83a9ea'                
            }
    
    def __init__(self, df, axis='auto', palette=None,
                 config='range', fig=None, ax=None):
        self.config = config
        if axis == 'auto':
            self.df = self.reshape_dataframe(df)
        elif axis == 1:
            self.df = df.transpose()
        elif axis == 0:
            self.df = df
        else:
            raise ValueError('The axis value needs to be 0, 1 or \'auto\'.')
        if palette is not None:
            self.palette = palette
        else:
            self.palette = self._std_palette

        if fig is not None:
            self.fig = fig
        if ax is not None:
            self.ax = ax
        if fig is None and ax is None:
            self.fig, self.ax = plt.subplots()

#         if self.config == 'range':
#             self.draw_span_selector()
#         elif self.config == 'constant':
#             self.draw_cursor()
            
        
        self.describe_columns()
        
        self.redraw()
#         self.draw_radio_buttons()
        self.draw_annotation()
#         self.radio.on_clicked(self.change_selector)
        for i in range(len(self.rects)):
            self.rects[i].set_color('#c5c5c5')
            self.rects[i].set_ec('#403530')
            self.rects[i].set_linestyle('--')

    def show(self):
        return plt.show()

    
    def on_pick(self, event):
        X, Y = event.xdata, event.ydata
        
        self.recolor_constant(Y)
#     def draw_radio_buttons(self):
#         self.radio_ax = plt.axes([0.025, 0.5, 0.15, 0.15],
#                                  facecolor=self.palette['widget_bg'])
#         self.radio = RadioButtons(self.radio_ax, ('constant', 'range'),
#                              active=0, activecolor=self.palette['widget_fg'])
        

    def describe_columns(self):
        self.descriptions = self.df.apply(lambda x: x.describe(), axis=0)
        sums = self.df.apply(lambda x: x.sum(), axis=0)
        stderrs = df.apply(lambda x: sem(x) * 1.96, axis=1)
        
        self.descriptions.loc['sum'] = sums
        self.descriptions.loc['stderr'] = stderrs

    def reshape_dataframe(self, df):
        """Will reshape the dataframe based on its shape, preferring
        a longer dataframe shape than a wider one; will transpose self.df
        in case of a wider one.
        """
        rows, cols = df.shape
        if rows > cols:
            return df
        else:
            return df.transpose()

    def draw_annotation(self):
        trans = self.ax.get_xaxis_transform() # x in data untis, y in axes fraction
        self.annot = self.ax.annotate('', xy=(-2.6, 0.1 ), xycoords=trans,
                                 bbox=dict(boxstyle='round', fc=self.palette['widget_bg']))
        self.annot.set_visible(False)
        self.fig.canvas.draw_idle()

    def redraw(self):
        ind = np.arange(len(self.df.columns))
        self.ax.cla()
        self.rects = self.ax.bar(ind, self.descriptions.loc['mean'], 0.95, color='b',
                                 yerr=self.descriptions.loc['stderr'], capsize=3)
        self.ax.set_xticks(ind)
        self.ax.set_xticklabels(self.df.columns)
        
        if self.config == 'range':
            self.draw_span_selector()
        elif self.config == 'constant':
            self.draw_cursor()
            self.cid = self.fig.canvas.mpl_connect('button_press_event', self.on_pick)
        
        self.fig.canvas.draw_idle()
    
    def update_annotation(self, vmin, vmax=None):
        if self.config == 'range':
            text = 'Selection:\n VMAX: {}\n VMIN: {}'.format(
                round(vmax,2),
                round(vmin,2))
        elif self.config == 'constant':
            text = 'Selection:\n Val: {}'.format(
                round(vmin,2))
        self.annot.set_text(text)
        self.annot.set_visible(True)
        self.fig.canvas.draw_idle()

        
    def recolor_range(self, vmin, vmax):
        self.update_annotation(vmin, vmax)
        self.redraw()
        for i in range(len(self.rects)):
            height = self.rects[i].get_height()
            stderr = self.descriptions.loc['stderr'][self.df.columns[i]]
            
            if y_value >= height - (stderr / 2) and y_value < height + (stderr / 2):
                if y_value == height:
                    self.rects[i].set_color(self.palette['range_gradient'][5])
                elif y_value > height:
                    _int = int((1 - ((y_value - height) / (stderr / 2))) * 5)
                    self.rects[i].set_color(self.palette['range_gradient'][_int])
                elif y_value < height:
                    _int = int((((height - y_value) / (stderr / 2))) * 5) + 5
                    self.rects[i].set_color(self.palette['range_gradient'][_int])
            elif y_value > height:
                self.rects[i].set_color(self.palette['range_gradient'][0])
            elif y_value < height:
                self.rects[i].set_color(self.palette['range_gradient'][10])
        self.fig.canvas.draw_idle()
        self.update_annotation(vmin=y_value)

    def recolor_constant(self, y_value):
        self.redraw()
        
        for i in range(len(self.rects)):
            height = self.rects[i].get_height()
            stderr = self.descriptions.loc['stderr'][self.df.columns[i]]
            
            if y_value >= height - (stderr / 2) and y_value < height + (stderr / 2):
                if y_value == height:
                    self.rects[i].set_color(self.palette['const_gradient'][5])
                elif y_value > height:
                    _int = int((1 - ((y_value - height) / (stderr / 2))) * 5)
                    self.rects[i].set_color(self.palette['const_gradient'][_int])
                elif y_value < height:
                    _int = int((((height - y_value) / (stderr / 2))) * 5) + 5
                    self.rects[i].set_color(self.palette['const_gradient'][_int])
            elif y_value > height:
                self.rects[i].set_color(self.palette['const_gradient'][0])
            elif y_value < height:
                self.rects[i].set_color(self.palette['const_gradient'][10])
            
            self.rects[i].set_ec('#403530')
            self.rects[i].set_linestyle('--')
        self.fig.canvas.draw_idle()
        self.update_annotation(vmin=y_value)

    def draw_cursor(self):
        self.cursor = Cursor(self.ax,
                                 color=self.palette['widget_fg'], lw=1,
                                 horizOn=True, vertOn=False)
        
    def draw_span_selector(self):
        self.span = SpanSelector(self.ax, self.recolor_range, 'vertical',
                                 rectprops=dict(facecolor=self.palette['widget_fg'],
                                                alpha=0.5),
                                span_stays=True)

# %%
fig = plt.figure()
fig.set_size_inches(9, 4, forward=True)
gspec = GridSpec(1,2)
ax1 = plt.subplot(gspec[0,0])
ax2 = plt.subplot(gspec[0,1])

# plt.figure()
# gspec = gridspec.GridSpec(3, 3)

# top_histogram = plt.subplot(gspec[0, 1:])

const_plot = InteractiveBarChart(df, fig=fig, ax=ax1, config='constant')
range_plot = InteractiveBarChart(df, fig=fig, ax=ax2, config='range')
# Out:
# <img src="data:image/png;base64,..." width="898.8889127013131">

# %%
const_plot.recolor_constant(42000)
# Out:
# this happened

# %%
# import matplotlib.pyplot as plt
# import matplotlib.widgets as mwidgets
# fig, ax = plt.subplots()
# ax.plot([1, 2, 3], [10, 50, 100])
# def onselect(vmin, vmax):
#         print(vmin, vmax)
# rectprops = dict(facecolor='blue', alpha=0.5)
# span = mwidgets.SpanSelector(ax, onselect, 'vertical',
#                                  rectprops=rectprops)
# fig.show()

# %%
# from matplotlib.widgets import MultiCursor
# import matplotlib.pyplot as plt
# # from pylab import figure, show, np

# t = np.arange(0.0, 2.0, 0.01)
# s1 = np.sin(2*np.pi*t)
# s2 = np.sin(4*np.pi*t)
# fig, ax1 = plt.subplots()
# ax1.plot(t, s1)

# ax2 = fig.add_subplot(212, sharex=ax1)
# ax2.plot(t, s2)

# multi = MultiCursor(fig.canvas, (ax1, ax2), color='r', lw=1,
#                     horizOn=True, vertOn=False)
# fig.show()

# %%
# from __future__ import print_function
# """
# Do a mouseclick somewhere, move the mouse to some destination, release
# the button.  This class gives click- and release-events and also draws
# a line or a box from the click-point to the actual mouseposition
# (within the same axes) until the button is released.  Within the
# method 'self.ignore()' it is checked whether the button from eventpress
# and eventrelease are the same.

# """
# from matplotlib.widgets import RectangleSelector
# import numpy as np
# import matplotlib.pyplot as plt


# def line_select_callback(eclick, erelease):
#     'eclick and erelease are the press and release events'
#     x1, y1 = eclick.xdata, eclick.ydata
#     x2, y2 = erelease.xdata, erelease.ydata
#     print("(%3.2f, %3.2f) --> (%3.2f, %3.2f)" % (x1, y1, x2, y2))
#     print(" The button you used were: %s %s" % (eclick.button, erelease.button))


# def toggle_selector(event):
#     print(' Key pressed.')
#     if event.key in ['Q', 'q'] and toggle_selector.RS.active:
#         print(' RectangleSelector deactivated.')
#         toggle_selector.RS.set_active(False)
#     if event.key in ['A', 'a'] and not toggle_selector.RS.active:
#         print(' RectangleSelector activated.')
#         toggle_selector.RS.set_active(True)


# fig, current_ax = plt.subplots()                 # make a new plotting range
# N = 100000                                       # If N is large one can see
# x = np.linspace(0.0, 10.0, N)                    # improvement by use blitting!

# plt.plot(x, +np.sin(.2*np.pi*x), lw=3.5, c='b', alpha=.7)  # plot something
# plt.plot(x, +np.cos(.2*np.pi*x), lw=3.5, c='r', alpha=.5)
# plt.plot(x, -np.sin(.2*np.pi*x), lw=3.5, c='g', alpha=.3)

# print("\n      click  -->  release")

# # drawtype is 'box' or 'line' or 'none'
# toggle_selector.RS = RectangleSelector(current_ax, line_select_callback,
#                                        drawtype='box', useblit=False,
#                                        button=[1, 3],  # don't use middle button
#                                        minspanx=100, minspany=5,
#                                        spancoords='pixels',
#                                        interactive=True)
# plt.connect('key_press_event', toggle_selector)
# plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
#       click  -->  release

# %%
# from matplotlib.pyplot import figure, show, cm
# from numpy import arange
# from numpy.random import rand


# def gbar(ax, x, y, width=0.5, bottom=0):
#     X = [[.6, .6], [.7, .7]]
#     for left, top in zip(x, y):
#         right = left + width
#         ax.imshow(X, interpolation='bicubic', cmap=cm.Blues,
#                   extent=(left, right, bottom, top), alpha=1)

# fig = figure()

# xmin, xmax = xlim = 0, 10
# ymin, ymax = ylim = 0, 1
# ax = fig.add_subplot(111, xlim=xlim, ylim=ylim,
#                      autoscale_on=False)
# X = [[.6, .9], [.7, .7]]

# # ax.imshow(X, interpolation='bicubic', cmap=cm.Blues,
# #           extent=(xmin, xmax, ymin, ymax), alpha=1)

# N = 11
# x = arange(N) + 0.29
# y = rand(N)
# gbar(ax, x, y, width=0.7)
# ax.set_aspect('auto')
# show()
# Out:
# <img src="data:image/png;base64,..." width="640">
